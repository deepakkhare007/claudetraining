# %%
# Load env variables and create client
from dotenv import load_dotenv
from anthropic import Anthropic

load_dotenv()

client = Anthropic()
model = "claude-haiku-4-5"

# %%
# Helper functions
def add_user_message(messages, text):
    user_message = {"role": "user", "content": text}
    messages.append(user_message)


def add_assistant_message(messages, text):
    assistant_message = {"role": "assistant", "content": text}
    messages.append(assistant_message)


def chat(messages, system=None, temperature=1.0, stop_sequences=[]):
    params = {
        "model": model,
        "max_tokens": 1000,
        "messages": messages,
        "temperature": temperature,
        "stop_sequences": stop_sequences,
    }

    if system:
        params["system"] = system

    message = client.messages.create(**params)
    return message.content[0].text

# %%
# Function to generate a new dataset
import json


def generate_dataset():
    prompt = """
Generate a evaluation dataset for a prompt evaluation. The dataset will be used to evaluate prompts
that generate Python, JSON, or Regex specifically for AWS-related tasks. Generate an array of JSON objects,
each representing task that requires Python, JSON, or a Regex to complete.

Example output:
```json
[
    {
        "task": "Description of task",
        "format": "json" or "python" or "regex"
    },
    ...additional
]
```

* Focus on tasks that can be solved by writing a single Python function, a single JSON object, or a regular expression.
* Focus on tasks that do not require writing much code

Please generate 3 objects.
"""

    messages = []
    add_user_message(messages, prompt)
    add_assistant_message(messages, "```json")
    text = chat(messages, stop_sequences=["```"])
    return json.loads(text)

# %%
# Generate the dataset and write it to 'dataset.json'
dataset = generate_dataset()
with open("dataset.json", "w") as f:
    json.dump(dataset, f, indent=2)

# %%
# Function to grade a test case + output using a model
def grade_by_model(test_case, output):
    eval_prompt = f"""
You are an expert AWS code reviewer. Your task is to evaluate the following AI-generated solution.

Original Task:
<task>
{test_case["task"]}
</task>

Solution to Evaluate:
<solution>
{output}
</solution>

Output Format
Provide your evaluation as a structured JSON object with the following fields, in this specific order:
- "strengths": An array of 1-3 key strengths
- "weaknesses": An array of 1-3 key areas for improvement
- "reasoning": A concise explanation of your overall assessment
- "score": A number between 1-10

Respond with JSON. Keep your response concise and direct.
Example response shape:
{{
    "strengths": string[],
    "weaknesses": string[],
    "reasoning": string,
    "score": number
}}
    """

    messages = []
    add_user_message(messages, eval_prompt)
    add_assistant_message(messages, "```json")
    eval_text = chat(messages, stop_sequences=["```"])
    return json.loads(eval_text)

# %%
# Passes a test case into Claude
def run_prompt(test_case):
    prompt = f"""
Please solve the following task:

{test_case["task"]}
"""

    messages = []
    add_user_message(messages, prompt)
    output = chat(messages)
    return output

# %%
# Function to execute a single test case and grade the output
def run_test_case(test_case):
    """Calls run_prompt, then grades the result"""
    output = run_prompt(test_case)

    model_grade = grade_by_model(test_case, output)
    score = model_grade["score"]
    reasoning = model_grade["reasoning"]

    return {
        "output": output,
        "test_case": test_case,
        "score": score,
        "reasoning": reasoning,
    }

# %%
from statistics import mean


def run_eval(dataset):
    """Loads the dataset and calls run_test_case with each case"""
    results = []

    for test_case in dataset:
        result = run_test_case(test_case)
        results.append(result)

    average_score = mean([result["score"] for result in results])
    print(f"Average score: {average_score}")

    return results

# %%
with open("dataset.json", "r") as f:
    dataset = json.load(f)

results = run_eval(dataset)
# Out:
# Average score: 6.666666666666667

# %%
print(json.dumps(results, indent=2))
# Out:
# [
#   {
#     "output": "# Parse AWS S3 Bucket Name from S3 URI\n\nHere are several solutions:\n\n## Solution 1: Using String Methods (Simplest)\n```python\ndef get_bucket_name(s3_uri):\n    \"\"\"Extract bucket name from S3 URI\"\"\"\n    return s3_uri.replace(\"s3://\", \"\").split(\"/\")[0]\n\n# Example usage\ns3_uri = \"s3://my-bucket/path/to/key\"\nbucket_name = get_bucket_name(s3_uri)\nprint(bucket_name)  # Output: my-bucket\n```\n\n## Solution 2: Using Regular Expressions\n```python\nimport re\n\ndef get_bucket_name(s3_uri):\n    \"\"\"Extract bucket name from S3 URI using regex\"\"\"\n    match = re.match(r\"s3://([^/]+)\", s3_uri)\n    if match:\n        return match.group(1)\n    raise ValueError(f\"Invalid S3 URI: {s3_uri}\")\n\n# Example usage\ns3_uri = \"s3://my-bucket/path/to/key\"\nbucket_name = get_bucket_name(s3_uri)\nprint(bucket_name)  # Output: my-bucket\n```\n\n## Solution 3: Using urllib (Most Robust)\n```python\nfrom urllib.parse import urlparse\n\ndef get_bucket_name(s3_uri):\n    \"\"\"Extract bucket name from S3 URI using urlparse\"\"\"\n    parsed = urlparse(s3_uri)\n    if parsed.scheme != \"s3\":\n        raise ValueError(f\"Invalid S3 URI: {s3_uri}\")\n    return parsed.netloc\n\n# Example usage\ns3_uri = \"s3://my-bucket/path/to/key\"\nbucket_name = get_bucket_name(s3_uri)\nprint(bucket_name)  # Output: my-bucket\n```\n\n## Test Cases\n```python\ntest_uris = [\n    \"s3://my-bucket/key\",\n    \"s3://bucket-with-dashes/path/to/file.txt\",\n    \"s3://bucket123/\",\n    \"s3://bucket\",\n]\n\nfor uri in test_uris:\n    print(get_bucket_name(uri))\n```\n\n**Recommendation:** Use **Solution 3 (urllib)** for production code as it's the most robust and handles edge cases properly.",
#     "test_case": {
#       "task": "Parse an AWS S3 bucket name from an S3 URI (s3://bucket-name/key/path) and extract just the bucket name",
#       "format": "regex"
#     },
#     "score": 7,
#     "reasoning": "The solution correctly identifies urllib.parse as the recommended approach and demonstrates good pedagogical structure by showing progressive complexity. However, it omits important AWS-specific URI formats and doesn't mention boto3's built-in parsing capabilities, which would be more idiomatic for AWS code. Solution 3 is solid for basic s3:// URI parsing but the recommendation could be stronger by acknowledging boto3's S3Url or similar utilities for production AWS applications."
#   },
#   {
#     "output": "# AWS IAM Role CloudFormation Template for EC2\n\n```json\n{\n  \"AWSTemplateFormatVersion\": \"2010-09-09\",\n  \"Description\": \"CloudFormation template for EC2 IAM Role with assume role policy\",\n  \"Resources\": {\n    \"EC2InstanceRole\": {\n      \"Type\": \"AWS::IAM::Role\",\n      \"Properties\": {\n        \"RoleName\": \"EC2InstanceRole\",\n        \"AssumeRolePolicyDocument\": {\n          \"Version\": \"2012-10-17\",\n          \"Statement\": [\n            {\n              \"Effect\": \"Allow\",\n              \"Principal\": {\n                \"Service\": \"ec2.amazonaws.com\"\n              },\n              \"Action\": \"sts:AssumeRole\"\n            }\n          ]\n        },\n        \"Description\": \"Role for EC2 instances to assume\",\n        \"Tags\": [\n          {\n            \"Key\": \"Environment\",\n            \"Value\": \"Production\"\n          }\n        ]\n      }\n    },\n    \"EC2InstanceProfile\": {\n      \"Type\": \"AWS::IAM::InstanceProfile\",\n      \"Properties\": {\n        \"InstanceProfileName\": \"EC2InstanceProfile\",\n        \"Roles\": [\n          {\n            \"Ref\": \"EC2InstanceRole\"\n          }\n        ]\n      }\n    },\n    \"EC2RolePolicy\": {\n      \"Type\": \"AWS::IAM::ManagedPolicy\",\n      \"Properties\": {\n        \"ManagedPolicyName\": \"EC2RolePolicy\",\n        \"PolicyDocument\": {\n          \"Version\": \"2012-10-17\",\n          \"Statement\": [\n            {\n              \"Effect\": \"Allow\",\n              \"Action\": [\n                \"s3:GetObject\",\n                \"s3:ListBucket\"\n              ],\n              \"Resource\": \"*\"\n            }\n          ]\n        },\n        \"Roles\": [\n          {\n            \"Ref\": \"EC2InstanceRole\"\n          }\n        ]\n      }\n    }\n  },\n  \"Outputs\": {\n    \"RoleArn\": {\n      \"Description\": \"ARN of the EC2 IAM Role\",\n      \"Value\": {\n        \"Fn::GetAtt\": [\"EC2InstanceRole\", \"Arn\"]\n      }\n    },\n    \"InstanceProfileArn\": {\n      \"Description\": \"ARN of the Instance Profile\",\n      \"Value\": {\n        \"Fn::GetAtt\": [\"EC2InstanceProfile\", \"Arn\"]\n      }\n    }\n  }\n}\n```\n\n## Key Components:\n\n| Component | Purpose |\n|-----------|---------|\n| **EC2InstanceRole** | IAM role with EC2 assume role policy |\n| **AssumeRolePolicyDocument** | Allows EC2 service to assume this role |\n| **EC2InstanceProfile** | Required wrapper to attach role to EC2 instances |\n| **EC2RolePolicy** | Example IAM policy with S3 permissions |\n\n## Usage:\n\n```bash\naws cloudformation create-stack \\\n  --stack-name ec2-iam-role-stack \\\n  --template-body file://template.json \\\n  --capabilities CAPABILITY_NAMED_IAM\n```\n\nThis template creates a ready-to-use IAM role for EC2 instances with an instance profile for attachment to your EC2 instances.",
#     "test_case": {
#       "task": "Create a JSON CloudFormation template snippet that defines an AWS IAM role with assume role policy for EC2",
#       "format": "json"
#     },
#     "score": 7,
#     "reasoning": "The solution successfully delivers a valid CloudFormation template that fulfills the core task of defining an IAM role with EC2 assume role policy. The template is well-structured and includes helpful extras like instance profile and example policy. However, it contains security and design concerns: the S3 permissions violate least privilege practices with overly broad resource access, and the hardcoded resource names limit flexibility. These are important considerations for production use, though the template would function correctly as-is."
#   },
#   {
#     "output": "# AWS ARN Format Validator\n\nHere's a comprehensive solution to validate AWS ARN format:\n\n```python\nimport re\nfrom typing import Tuple\n\ndef is_valid_arn(arn: str) -> bool:\n    \"\"\"\n    Validates if a given string is a valid AWS ARN format.\n    \n    AWS ARN Format: arn:partition:service:region:account-id:resource-type/resource-id\n    \n    Args:\n        arn: String to validate as an AWS ARN\n        \n    Returns:\n        bool: True if valid ARN format, False otherwise\n        \n    Example:\n        >>> is_valid_arn(\"arn:aws:s3:::my-bucket\")\n        True\n        >>> is_valid_arn(\"arn:aws:iam::123456789012:user/Development/product_1234/*\")\n        True\n        >>> is_valid_arn(\"invalid-arn\")\n        False\n    \"\"\"\n    \n    # Basic ARN pattern\n    # arn:partition:service:region:account-id:resource\n    arn_pattern = r'^arn:[a-z0-9\\-]*:[a-z0-9\\-]*:[a-z0-9\\-]*:[0-9]*:[a-z0-9\\-_/:*]+'\n    \n    if not isinstance(arn, str):\n        return False\n    \n    if not re.match(arn_pattern, arn, re.IGNORECASE):\n        return False\n    \n    return True\n\n\ndef validate_arn_detailed(arn: str) -> Tuple[bool, dict]:\n    \"\"\"\n    Validates AWS ARN format and returns detailed information.\n    \n    Args:\n        arn: String to validate as an AWS ARN\n        \n    Returns:\n        Tuple containing:\n        - bool: True if valid ARN\n        - dict: Details about the ARN components or error message\n        \n    Example:\n        >>> is_valid, details = validate_arn_detailed(\"arn:aws:ec2:us-east-1:123456789012:instance/i-1234567890abcdef0\")\n        >>> print(is_valid, details)\n        True {'partition': 'aws', 'service': 'ec2', ...}\n    \"\"\"\n    \n    # More detailed ARN pattern with capture groups\n    arn_pattern = r'^arn:([a-z0-9\\-]+):([a-z0-9\\-]+):([a-z0-9\\-]*):([0-9]*):(.+)$'\n    \n    if not isinstance(arn, str):\n        return False, {\"error\": \"Input must be a string\"}\n    \n    arn = arn.strip()\n    \n    match = re.match(arn_pattern, arn, re.IGNORECASE)\n    \n    if not match:\n        return False, {\"error\": \"Invalid ARN format\"}\n    \n    partition, service, region, account_id, resource = match.groups()\n    \n    details = {\n        \"partition\": partition,\n        \"service\": service,\n        \"region\": region if region else None,\n        \"account_id\": account_id if account_id else None,\n        \"resource\": resource,\n        \"is_valid\": True\n    }\n    \n    return True, details\n\n\n# Test cases\nif __name__ == \"__main__\":\n    \n    # Valid ARNs\n    valid_arns = [\n        \"arn:aws:s3:::my-bucket\",\n        \"arn:aws:s3:::my-bucket/my-object\",\n        \"arn:aws:iam::123456789012:user/Development/product_1234/*\",\n        \"arn:aws:iam::123456789012:role/service-role/MyRole\",\n        \"arn:aws:ec2:us-east-1:123456789012:instance/i-1234567890abcdef0\",\n        \"arn:aws:dynamodb:us-east-1:123456789012:table/my-table\",\n        \"arn:aws:lambda:us-west-2:123456789012:function:my-function\",",
#     "test_case": {
#       "task": "Write a Python function that validates if a given string is a valid AWS ARN format",
#       "format": "python"
#     },
#     "score": 6,
#     "reasoning": "The solution demonstrates good code structure and documentation practices with dual validation functions serving different use cases. However, it suffers from regex patterns that are too permissive for production use - they would accept invalid ARNs that don't comply with actual AWS ARN specifications. The incomplete test suite prevents verification that the validators work correctly. While suitable for basic string format checking, it lacks the rigor needed for strict AWS ARN validation."
#   }
# ]
